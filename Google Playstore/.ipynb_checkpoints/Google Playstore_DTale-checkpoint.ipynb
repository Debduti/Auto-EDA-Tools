# %%
pip install dtale
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Collecting dash_renderer==1.8.3
# ...
#   Created wheel for dash: filename=dash-1.18.0-py3-none-any.whl size=83689 sha256=a5f9ed571bfdd761a0c21d3ebf4ff83641bc6d9479098cc1c90ce2886aa45eaf
#   Stored in directory: c:\users\debdu\appdata\local\pip\cache\wheels\10\27\3d\3432718b5d26040e2478839f2d1cf5ecebc2edda83e8d93787
# ...
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62603 sha256=368bf9d53d023a82b2e7f9ee9110924d8ac4387fba1db4f840cbcafa89fe76cb
#   Stored in directory: c:\users\debdu\appdata\local\pip\cache\wheels\fe\33\33\172dbfe1efc739352828854a113df599a428b58f68ed0c4f75
# ...
#   Created wheel for ppscore: filename=ppscore-1.1.1-py2.py3-none-any.whl size=12992 sha256=2c02ca1983ec97a46ce02996fd3cc7fb819f768a820c5803fdfa314f1bde743e
#   Stored in directory: c:\users\debdu\appdata\local\pip\cache\wheels\e1\45\ce\6bb5da9f22f466ba4e0ef6e3a3d2bbcde992f96c550165fc60
# ...

# %%
import pandas as pd
import dtale

# %%
df = pd.read_csv('../Google Playstore/archive (4)/googleplaystore.csv')

# %%
# check the dataframe and view the first 5 rows
pd.set_option('display.max_columns', None)
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#EDA using dtale
dtale.show(pd.read_csv('../Google Playstore/archive (4)/googleplaystore.csv'))
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-51HEH6L2:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
